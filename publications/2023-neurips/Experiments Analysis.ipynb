# %%
import pandas as pd
import sqlite3

with sqlite3.connect("experiments.db") as con:
    df = pd.read_sql_query("SELECT * from lcdb_classification", con)

df
# Out:
#         ID  openmlid  seed_outer  seed_inner  \
# 0        1         3           0           0
# 1        2         3           0           0
# 2        3         3           0           0
# 3        4         3           0           0
# 4        5         3           0           0
# ...    ...       ...         ...         ...
# 3523  3524       871           0           0
# 3524  3525       871           0           0
# 3525  3526       871           0           0
# 3526  3527       871           0           0
# 3527  3528       871           0           0
#
#                                  train_size  \
# 0     [16,32,64,128,256,512,1024,2048,2588]
# 1     [16,32,64,128,256,512,1024,2048,2588]
# 2     [16,32,64,128,256,512,1024,2048,2588]
# 3     [16,32,64,128,256,512,1024,2048,2588]
# 4     [16,32,64,128,256,512,1024,2048,2588]
# ...                                     ...
# 3523  [16,32,64,128,256,512,1024,2048,3116]
# 3524  [16,32,64,128,256,512,1024,2048,3116]
# ...

# %%
df
# Out:
#         ID  openmlid  seed_outer  seed_inner  \
# 0        1         3           0           0
# 1        2         3           0           0
# 2        3         3           0           0
# 3        4         3           0           0
# 4        5         3           0           0
# ...    ...       ...         ...         ...
# 3523  3524       871           0           0
# 3524  3525       871           0           0
# 3525  3526       871           0           0
# 3526  3527       871           0           0
# 3527  3528       871           0           0
#
#                                  train_size  \
# 0     [16,32,64,128,256,512,1024,2048,2588]
# 1     [16,32,64,128,256,512,1024,2048,2588]
# 2     [16,32,64,128,256,512,1024,2048,2588]
# 3     [16,32,64,128,256,512,1024,2048,2588]
# 4     [16,32,64,128,256,512,1024,2048,2588]
# ...                                     ...
# 3523  [16,32,64,128,256,512,1024,2048,3116]
# 3524  [16,32,64,128,256,512,1024,2048,3116]
# ...
